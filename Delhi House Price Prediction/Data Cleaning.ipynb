# %% [markdown]
# # Data Science Regression Project: Predicting Home Prices in Delhi

# %% [markdown]
# Dataset is downloaded from here: https://www.kaggle.com/amitabhajoy/bengaluru-house-price-data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"]=(20,10)

# %% [markdown]
# ### Data Load: Loading Delhi home prices into a dataframe

# %%
df=pd.read_csv('Delhi.csv',encoding='latin1')
df
# Out:
#       Unnamed: 0     price                                            Address  \
# 0              0   5600000                  Noida Extension, Noida, Delhi NCR
# 1              1   8800000                      Sector 79, Gurgaon, Delhi NCR
# 2              2  16500000                     Vaishali, Ghaziabad, Delhi NCR
# 3              3   3810000  Link Road, F Block, Sector 50, Noida, Uttar Pr...
# 4              4   6200000  Jaypee Pavilion Court Sector 128, Noida, Secto...
# ...          ...       ...                                                ...
# 7733        7733   7900000                  Indirapuram, Ghaziabad, Delhi NCR
# 7734        7734   4510000  Greater Noida, Sector 2, Greater Noida, Delhi NCR
# 7735        7735   7000000           Crossings Republik, Ghaziabad, Delhi NCR
# 7736        7736   6500000  Raj Nagar Extension, Ghaziabad, Raj Nagar Exte...
# 7737        7737   6500000  sandal apartment, Shalimar Garden Extension 1,...
#
#       area   latitude  longitude  Bedrooms  Bathrooms  Balcony  \
# 0     1350  28.608850  77.460560         3          3      NaN
# 1     1490  28.374236  76.952416         3          3      NaN
# 2     2385  28.645769  77.385110         4          5      NaN
# 3     1050  28.566914  77.436434         2          2      3.0
# 4     1350  28.520732  77.356491         2          2      3.0
# ...    ...        ...        ...       ...        ...      ...
# 7733  1095  28.635272  77.370395         2          2      NaN
# 7734  1060  28.581431  77.452819         2          2      3.0
# 7735  1898  28.625850  77.435336         4          3      5.0
# 7736  1400  28.701622  77.430153         3          3      2.0
# 7737  1750  28.693590  77.344376         3          2      3.0
#
#                   Status      neworold  parking Furnished_status  Lift  \
# 0     Under Construction  New Property      NaN              NaN   2.0
# 1          Ready to Move  New Property      NaN   Semi-Furnished   2.0
# 2          Ready to Move  New Property      1.0      Unfurnished   NaN
# 3                    NaN  New Property      1.0      Unfurnished   2.0
# 4          Ready to Move        Resale      1.0              NaN   3.0
# ...                  ...           ...      ...              ...   ...
# 7733       Ready to Move        Resale      NaN              NaN   NaN
# 7734                 NaN        Resale      NaN   Semi-Furnished   NaN
# 7735       Ready to Move        Resale      NaN              NaN   NaN
# 7736       Ready to Move        Resale      1.0              NaN   3.0
# 7737       Ready to Move  New Property      NaN              NaN   NaN
#
#                        Landmarks type_of_building  \
# 0                            NaN             Flat
# 1                            NaN             Flat
# 2                            NaN             Flat
# 3     near Gaur Mulberry Mansion             Flat
# 4                            NaN             Flat
# ...                          ...              ...
# 7733                         NaN             Flat
# 7734              ek murti chowk             Flat
# 7735                         NaN             Flat
# 7736                   vvip mall             Flat
# 7737                         NaN             Flat
#
#                                                    desc   Price_sqft
# 0     \n\n\n                                Welcome ...  4148.148148
# 1     \n\n\n                                Mapsko M...  5906.040268
# 2     \n\n\n                                This pro...  6918.238994
# 3     \n\n\n                                AIG Roya...  3628.571429
# 4     \n\n\n                                The prop...  4592.592593
# ...                                                 ...          ...
# 7733  \n                    \n                    \n...  7214.611872
# 7734  \n                    \n                    \n...  4254.716981
# 7735  \n                    \n                    \n...  3688.092729
# 7736  \n                    \n                    \n...  4642.857143
# 7737                                                 \n  3714.285714
#
# [7738 rows x 18 columns]

# %%
df.shape
# Out:
# (7738, 18)

# %% [markdown]
# Drop features that are not required to build our model

# %%
df=df.drop(['Unnamed: 0','latitude','longitude','Status','desc','Landmarks','neworold','Balcony','parking','Lift'],axis=1)
df
# Out:
#          price                                            Address  area  \
# 0      5600000                  Noida Extension, Noida, Delhi NCR  1350
# 1      8800000                      Sector 79, Gurgaon, Delhi NCR  1490
# 2     16500000                     Vaishali, Ghaziabad, Delhi NCR  2385
# 3      3810000  Link Road, F Block, Sector 50, Noida, Uttar Pr...  1050
# 4      6200000  Jaypee Pavilion Court Sector 128, Noida, Secto...  1350
# ...        ...                                                ...   ...
# 7733   7900000                  Indirapuram, Ghaziabad, Delhi NCR  1095
# 7734   4510000  Greater Noida, Sector 2, Greater Noida, Delhi NCR  1060
# 7735   7000000           Crossings Republik, Ghaziabad, Delhi NCR  1898
# 7736   6500000  Raj Nagar Extension, Ghaziabad, Raj Nagar Exte...  1400
# 7737   6500000  sandal apartment, Shalimar Garden Extension 1,...  1750
#
#       Bedrooms  Bathrooms Furnished_status type_of_building   Price_sqft
# 0            3          3              NaN             Flat  4148.148148
# 1            3          3   Semi-Furnished             Flat  5906.040268
# 2            4          5      Unfurnished             Flat  6918.238994
# 3            2          2      Unfurnished             Flat  3628.571429
# 4            2          2              NaN             Flat  4592.592593
# ...        ...        ...              ...              ...          ...
# 7733         2          2              NaN             Flat  7214.611872
# 7734         2          2   Semi-Furnished             Flat  4254.716981
# 7735         4          3              NaN             Flat  3688.092729
# 7736         3          3              NaN             Flat  4642.857143
# 7737         3          2              NaN             Flat  3714.285714
#
# [7738 rows x 8 columns]

# %%
df.groupby('type_of_building')['type_of_building'].agg('count')
# Out:
# type_of_building
# Flat                6226
# Individual House    1512
# Name: type_of_building, dtype: int64

# %% [markdown]
# ### Data Cleaning: Handle NA values

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# Bedrooms               0
# Bathrooms              0
# Furnished_status    3614
# type_of_building       0
# Price_sqft             0
# dtype: int64

# %%
df=df.fillna('Unknown')
df
# Out:
#          price                                            Address  area  \
# 0      5600000                  Noida Extension, Noida, Delhi NCR  1350
# 1      8800000                      Sector 79, Gurgaon, Delhi NCR  1490
# 2     16500000                     Vaishali, Ghaziabad, Delhi NCR  2385
# 3      3810000  Link Road, F Block, Sector 50, Noida, Uttar Pr...  1050
# 4      6200000  Jaypee Pavilion Court Sector 128, Noida, Secto...  1350
# ...        ...                                                ...   ...
# 7733   7900000                  Indirapuram, Ghaziabad, Delhi NCR  1095
# 7734   4510000  Greater Noida, Sector 2, Greater Noida, Delhi NCR  1060
# 7735   7000000           Crossings Republik, Ghaziabad, Delhi NCR  1898
# 7736   6500000  Raj Nagar Extension, Ghaziabad, Raj Nagar Exte...  1400
# 7737   6500000  sandal apartment, Shalimar Garden Extension 1,...  1750
#
#       Bedrooms  Bathrooms Furnished_status type_of_building   Price_sqft
# 0            3          3          Unknown             Flat  4148.148148
# 1            3          3   Semi-Furnished             Flat  5906.040268
# 2            4          5      Unfurnished             Flat  6918.238994
# 3            2          2      Unfurnished             Flat  3628.571429
# 4            2          2          Unknown             Flat  4592.592593
# ...        ...        ...              ...              ...          ...
# 7733         2          2          Unknown             Flat  7214.611872
# 7734         2          2   Semi-Furnished             Flat  4254.716981
# 7735         4          3          Unknown             Flat  3688.092729
# 7736         3          3          Unknown             Flat  4642.857143
# 7737         3          2          Unknown             Flat  3714.285714
#
# [7738 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# price               0
# Address             0
# area                0
# Bedrooms            0
# Bathrooms           0
# Furnished_status    0
# type_of_building    0
# Price_sqft          0
# dtype: int64

# %%
df.dtypes
# Out:
# price                 int64
# Address              object
# area                  int64
# Bedrooms              int64
# Bathrooms             int64
# Furnished_status     object
# type_of_building     object
# Price_sqft          float64
# dtype: object
